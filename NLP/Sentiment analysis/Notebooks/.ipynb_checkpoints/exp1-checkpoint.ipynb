# %%
# !pip install -U scikit-learn
# !pip install matplotlib
# !pip install numpy
# !pip3 install glob3
# !pip install nltk
# !pip install pandas

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import pandas as pd
from sklearn.model_selection import KFold,train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
import unicodedata
from nltk.cluster import KMeansClusterer
from sklearn.cluster import MiniBatchKMeans
import nltk.data
import nltk.corpus
from nltk.corpus import wordnet
from nltk import WordNetLemmatizer

from util import CorpusLoader

# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')

# %%
corpus = CorpusLoader('../datasets/*.txt')
df = corpus.df
df.head()

# %%
class TextNormalizer(BaseEstimator, TransformerMixin):

    def __init__(self, lang='english'):
        self.stopwords = set(nltk.corpus.stopwords.words(lang))
        self.lemmatizer = WordNetLemmatizer()

    def is_stopword(self, token: str) -> bool:
        return token.lower() in self.stopwords

    def is_punct(self, token: str) -> bool:
        return all(unicodedata.category(char).startswith('P') for char in token)

    def lemmatize_pos(self, token:str, tag):
        
        tagger = {
            'N': wordnet.NOUN,
            'V': wordnet.VERB,
            'R': wordnet.ADV,
            'J': wordnet.ADJ
        }.get(tag, wordnet.NOUN)

        return self.lemmatizer.lemmatize(token, tagger)

    def normalize(self, instances):
        data = []
        for ins in instances:
            current_sen = nltk.pos_tag(nltk.word_tokenize(ins))
            
            data.append(' '.join([
                self.lemmatize_pos(token, pos) for token, pos in current_sen
                if not self.is_punct(token) and not self.is_stopword(token)
            ]))
        return np.array(data)
            
    def fit(self, X, y=None):
        return self

    def transform(self, instances):
        return self.normalize(instances)

# %%
# model = Pipeline([
#         ('normalize',TextNormalizer()),
#         ('vectorizer', CountVectorizer(min_df=5,max_df=0.4,max_features=1500)),
#         ('clusterer', KMeansCluster()),
# ])

# %%
# clusters = model.fit_transform(corpus.df.instances)
normalizer = TextNormalizer()
norm = normalizer.transform(corpus.df.instances)
vec = CountVectorizer(min_df=3,max_df=0.7,max_features=1500)
# print(norm)
X = vec.fit_transform(norm)
# print(vec.get_feature_names())
# print(X.toarray()[0:5])
kmc = KMeansClusterer()
labels = kmc.fit_transform(X.toarray())
model = kmc.model
labels
# Out:
# array([4, 4, 3, 0, 4, 3, 6, 6, 4, 4, 1, 3, 3, 3, 3, 2, 2, 4, 4, 3, 5, 5,
#        5, 3, 0, 0, 4, 0, 4, 4, 4, 4, 3], dtype=int32)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
scatter_plot_points = pca.fit_transform(X.toarray())

colors = ["r", "b", "c", "y", "m" ,"y","g"]

x_axis = [o[0] for o in scatter_plot_points]
y_axis = [o[1] for o in scatter_plot_points]
fig, ax = plt.subplots(figsize=(20,10))

ax.scatter(x_axis, y_axis, c=[colors[d] for d in labels])

for i, txt in enumerate(corpus.df.instances):
    ax.annotate(txt, (x_axis[i], y_axis[i]))

# %%
plt.show()
